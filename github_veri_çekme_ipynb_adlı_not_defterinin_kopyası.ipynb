# %% [markdown]
# <a href="https://colab.research.google.com/github/emreyldz0671/BackGroundRemover/blob/master/github_veri_%C3%A7ekme_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rongardF/tvdatafeed tradingview-screener

import numpy as np
import pandas as pd
from tvDatafeed import TvDatafeed, Interval
from tradingview_screener import get_all_symbols
import warnings

warnings.simplefilter(action='ignore')

#Standart Moving Average
def sma(series, length):
    """
    Calculate the Simple Moving Average (SMA) for a given series.
    """
    return series.rolling(window=length).mean()

#Exponential Moving Average
def ema(series, length):
    """
    Calculate the Exponential Moving Average (EMA) for a given series.
    """
    return series.ewm(span=length, adjust=False).mean()


def Bankery(data):
    df=data.copy()
    close_minus_rolling_min = data['close'] - pd.Series(data['low']).rolling(window=27).min()
    percentage_change = close_minus_rolling_min / (pd.Series(data['high']).rolling(window=27).max() - pd.Series(data['low']).rolling(window=27).min()) * 100

    sma1 = sma(percentage_change, 5)
    sma2 = sma(sma1, 3)

    fundtrend = (3 * sma1 - 2 * sma2 - 50) * 1.032 + 50

    typ = (2 * data['close'] + data['high'] + data['low'] + data['open']) / 5
    lol = pd.Series(data['low']).rolling(window=34).min()
    hoh = pd.Series(data['high']).rolling(window=34).max()
    bullbearline = ema((typ - lol) / (hoh - lol) * 100, 13)
    bankerentry = (fundtrend > bullbearline) & (bullbearline < 25)
    df['Entry'] = (bankerentry==True)
    return df


tv = TvDatafeed()
Hisseler = get_all_symbols(market='turkey')
Hisseler = [symbol.replace('BIST:', '') for symbol in Hisseler]
Hisseler = sorted(Hisseler)


#Raporlama için kullanılacak başlıklar
Titles = ['Hisse Adı', 'Son Fiyat','Dip Sinyali']
df_signals = pd.DataFrame(columns=Titles)

for hisse in Hisseler:
    try:
        data = tv.get_hist(symbol=hisse, exchange='BIST', interval=Interval.in_1_hour, n_bars=100)
        data = data.reset_index()
        Banker = Bankery(data)
        Banker.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'}, inplace=True)
        Banker.set_index('datetime', inplace=True)
        Buy = False
        Signals = Banker.tail(2)
        Signals = Signals.reset_index()

        Entry = (Signals.loc[0, 'Entry'] == False) & (Signals.loc[1, 'Entry'] == True)
        Last_Price = Signals.loc[1, 'Close']
        L1 = [hisse, Last_Price,Entry]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except:
        pass

df_True = df_signals[(df_signals['Dip Sinyali'] == True)]
print(df_True)
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-xa31d_ey
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-xa31d_ey
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Collecting tradingview-screener
#   Downloading tradingview_screener-2.4.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (67.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.0.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Collecting pandas (from tvdatafeed==2.1.0)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=94926d2608e56245c867050917087229c4d52aeea7a03448a0a03baafcfab604
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xyj07d3d/wheels/e4/32/1e/21ebcacc6549d75fae3bf3ff75cee8fcbe4e5c189d88fbd5a1
# Successfully built tvdatafeed
# Installing collected packages: pandas, tvdatafeed, tradingview-screener
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# Successfully installed pandas-2.2.2 tradingview-screener-2.4.1 tvdatafeed-2.1.0
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# ['A1CAP', 27.36, False]
# ['ACSEL', 134.0, False]
# ['ADEL', 493.25, False]
# ['ADESE', 2.21, False]
# ['ADGYO', 30.0, False]
# ['AEFES', 225.5, False]
# ['AFYON', 12.8, False]
# ['AGESA', 122.6, False]
# ['AGHOL', 342.25, False]
# ['AGROT', 17.63, False]
# ['AGYO', 8.06, False]
# ['AHGAZ', 14.1, False]
# ['AKBNK', 61.1, False]
# ['AKCNS', 137.0, False]
# ['AKENR', 15.27, False]
# ['AKFGY', 2.29, False]
# ['AKFYE', 28.78, False]
# ['AKGRT', 8.18, False]
# ['AKMGY', 266.5, False]
# ['AKSA', 122.2, False]
# ['AKSEN', 44.7, False]
# ['AKSGY', 17.91, False]
# ['AKSUE', 12.19, False]
# ['AKYHO', 7.98, False]
# ['ALARK', 112.7, False]
# ['ALBRK', 5.55, False]
# ['ALBTS', 2662.0, False]
# ['ALCAR', 1370.0, False]
# ['ALCTL', 102.1, False]
# ['ALDUK', 6950.0, False]
# ['ALFAS', 67.6, False]
# ['ALGYO', 42.82, False]
# ['ALKA', 27.82, False]
# ['ALKIM', 33.96, False]
# ['ALKLC', 20.18, False]
# ['ALMAD', 6.79, False]
# ['ALTIN', 24.23, False]
# ['ALTNY', 84.3, False]
# ['ALVES', 41.32, False]
# ['ANELE', 18.32, False]
# ['ANGEN', 11.91, False]
# ['ANHYT', 131.1, False]
# ['ANSGR', 113.2, False]
# ['APBDL', 23.55, False]
# ['APLIB', 39.83, False]
# ['APX30', 27.34, False]
# ['APYKF', 1750.0, False]
# ['APYKS', 1476.0, False]
# ['APYMD', 3498.0, False]
# ['APYVC', 5000.0, False]
# ['ARASE', 59.55, False]
# ['ARCLK', 175.1, False]
# ['ARDYZ', 40.16, False]
# ['ARENA', 41.56, False]
# ['ARSAN', 17.5, False]
# ['ARTMS', 44.66, False]
# ['ARZUM', 65.0, False]
# ['ASELS', 59.35, False]
# ['ASGYO', 13.38, False]
# ['ASTOR', 94.0, False]
# ['ASUZU', 92.1, False]
# ['ATAGY', 13.05, False]
# ['ATAKP', 49.0, False]
# ['ATATP', 139.7, False]
# ['ATEKS', 157.0, False]
# ['ATLAS', 5.03, False]
# ['ATSYH', 43.1, False]
# ['AVGYO', 8.1, False]
# ['AVHOL', 35.74, False]
# ['AVOD', 3.44, False]
# ['AVPGY', 43.12, False]
# ['AVTUR', 15.95, False]
# ['AYCES', 639.0, False]
# ['AYDEM', 34.18, False]
# ['AYEN', 31.08, False]
# ['AYES', 46.1, False]
# ['AYGAZ', 174.4, False]
# ['AZTEK', 69.4, False]
# ['BAGFS', 23.28, False]
# ['BAKAB', 42.5, False]
# ['BALAT', 33.0, False]
# ['BANVT', 293.25, False]
# ['BARMA', 18.01, False]
# ['BASCM', 13.71, False]
# ['BASGZ', 30.24, False]
# ['BAYRK', 62.5, False]
# ['BEGYO', 3.9, False]
# ['BERA', 17.2, False]
# ['BEYAZ', 23.9, False]
# ['BFREN', 876.5, False]
# ['BIENY', 34.84, False]
# ['BIGCH', 31.8, False]
# ['BIMAS', 553.0, False]
# ['BINHO', 392.0, False]
# ['BIOEN', 20.18, False]
# ['BIZIM', 34.1, False]
# ['BJKAS', 33.3, False]
# ['BLCYT', 19.25, False]
# ['BMSCH', 24.9, False]
# ['BMSTL', 39.08, False]
# ['BNTAS', 12.1, False]
# ['BOBET', 28.3, False]
# ['BORLS', 33.1, False]
# ['BORSK', 31.88, False]
# ['BOSSA', 16.85, False]
# ['BRISA', 111.7, False]
# ['BRKO', 9.93, False]
# ['BRKSN', 37.62, False]
# ['BRKVY', 59.65, False]
# ['BRLSM', 18.62, False]
# ['BRMEN', 5.32, False]
# ['BRSAN', 474.0, False]
# ['BRYAT', 2305.0, False]
# ['BSOKE', 29.92, False]
# ['BTCIM', 145.0, False]
# ['BUCIM', 8.17, False]
# ['BURCE', 280.0, False]
# ['BURVA', 135.2, False]
# ['BVSAN', 105.0, False]
# ['BYDNR', 25.9, False]
# ['CANTE', 16.85, False]
# ['CASA', 84.0, False]
# ['CATES', 45.76, False]
# ['CCOLA', 806.0, False]
# ['CELHA', 24.04, False]
# ['CEMAS', 4.27, False]
# ['CEMTS', 12.3, False]
# ['CEOEM', 21.8, False]
# ['CIMSA', 30.52, False]
# ['CLEBI', 2127.0, False]
# ['CMBTN', 3020.0, False]
# ['CMENT', 400.0, False]
# ['CONSE', 5.39, False]
# ['COSMO', 125.0, False]
# ['CRDFA', 7.8, False]
# ['CRFSA', 117.9, False]
# ['CUSAN', 23.8, False]
# ['CVKMD', 473.75, False]
# ['CWENE', 202.2, False]
# ['DAGHL', 18.0, False]
# ['DAGI', 8.5, False]
# ['DAPGM', 32.48, False]
# ['DARDL', 6.2, False]
# ['DENGE', 4.56, False]
# ['DERHL', 7.46, False]
# ['DERIM', 44.6, False]
# ['DESA', 30.48, False]
# ['DESPC', 40.88, False]
# ['DEVA', 90.5, False]
# ['DGATE', 39.5, False]
# ['DGGYO', 33.24, False]
# ['DGNMO', 13.7, False]
# ['DIRIT', 21.6, False]
# ['DITAS', 15.95, False]
# ['DMRGD', 14.14, False]
# ['DMSAS', 7.05, False]
# ['DNISI', 15.8, False]
# ['DOAS', 275.25, False]
# ['DOBUR', 190.1, False]
# ['DOCO', 5370.0, False]
# ['DOFER', 39.16, False]
# ['DOGUB', 27.12, False]
# ['DOHOL', 15.95, False]
# ['DOKTA', 30.2, False]
# ['DURDO', 14.7, False]
# ['DYOBY', 50.85, False]
# ['DZGYO', 4.64, False]
# ['EBEBK', 44.46, False]
# ['ECILC', 53.15, False]
# ['ECZYT', 232.3, False]
# ['EDATA', 16.73, False]
# ['EDIP', 25.64, False]
# ['EGEEN', 12397.5, False]
# ['EGEPO', 20.4, False]
# ['EGGUB', 40.04, False]
# ['EGPRO', 225.5, False]
# ['EGSER', 3.52, False]
# ['EKGYO', 9.07, False]
# ['EKIZ', 77.2, False]
# ['EKOS', 34.92, False]
# ['EKSUN', 59.3, False]
# ['ELITE', 27.88, False]
# ['EMKEL', 12.65, False]
# ['EMNIS', 384.0, False]
# ['ENERY', 178.5, False]
# ['ENJSA', 63.7, False]
# ['ENKAI', 42.0, False]
# ['ENSRI', 19.74, False]
# ['ENTRA', 10.3, False]
# ['EPLAS', 7.04, False]
# ['ERBOS', 223.3, False]
# ['ERCB', 123.9, False]
# ['EREGL', 51.6, False]
# ['ERSU', 20.98, False]
# ['ESCAR', 332.0, False]
# ['ESCOM', 66.1, False]
# ['ESEN', 19.4, False]
# ['ETILR', 24.36, False]
# ['ETYAT', 14.75, False]
# ['EUHOL', 3.31, False]
# ['EUKYO', 22.42, False]
# ['EUPWR', 105.9, False]
# ['EUREN', 14.66, False]
# ['EUYO', 14.11, False]
# ['EYGYO', 11.07, False]
# ['FADE', 15.56, False]
# ['FENER', 152.0, False]
# ['FLAP', 7.9, False]
# ['FMIZP', 315.0, False]
# ['FONET', 16.96, False]
# ['FORMT', 3.06, False]
# ['FORTE', 55.85, False]
# ['FRIGO', 7.84, False]
# ['FROTO', 1079.0, False]
# ['FZLGY', 12.33, False]
# ['GARAN', 104.9, False]
# ['GARFA', 25.54, False]
# ['GEDIK', 14.32, False]
# ['GEDZA', 24.36, False]
# ['GENIL', 66.85, False]
# ['GENTS', 8.88, False]
# ['GEREL', 41.04, False]
# ['GESAN', 53.05, False]
# ['GIPTA', 31.74, False]
# ['GLBMD', 37.9, False]
# ['GLCVY', 40.54, False]
# ['GLDTR', 209.35, False]
# ['GLRYH', 11.75, False]
# ['GLYHO', 16.06, False]
# ['GMSTR', 196.1, False]
# ['GMTAS', 9.35, False]
# ['GOKNR', 21.9, False]
# ['GOLTS', 420.25, False]
# ['GOODY', 21.42, False]
# ['GOZDE', 26.56, False]
# ['GRNYO', 9.67, False]
# ['GRSEL', 133.4, False]
# ['GRTRK', 63.85, False]
# ['GSDDE', 9.79, False]
# ['GSDHO', 4.13, False]
# ['GSRAY', 8.23, False]
# ['GUBRF', 145.9, False]
# ['GWIND', 29.42, False]
# ['GZNMI', 35.12, False]
# ['HALKB', 19.48, False]
# ['HATEK', 13.27, False]
# ['HATSN', 52.3, False]
# ['HDFGS', 1.84, False]
# ['HEDEF', 25.2, False]
# ['HEKTS', 13.5, False]
# ['HKTM', 17.36, False]
# ['HLGYO', 2.95, False]
# ['HOROZ', 47.72, False]
# ['HRKET', 66.4, False]
# ['HTTBT', 66.05, False]
# ['HUBVC', 10.78, False]
# ['HUNER', 4.06, False]
# ['HURGZ', 4.0, False]
# ['ICBCT', 15.1, False]
# ['ICUGS', 13.4, False]
# ['IDGYO', 6.5, False]
# ['IEYHO', 5.06, False]
# ['IHAAS', 25.12, True]
# ['IHEVA', 3.58, False]
# ['IHGZT', 1.24, False]
# ['IHLAS', 1.32, False]
# ['IHLGM', 1.57, False]
# ['IHYAY', 5.04, False]
# ['IMASM', 14.07, False]
# ['INDES', 8.65, False]
# ['INFO', 10.33, False]
# ['INGRM', 515.5, False]
# ['INTEM', 253.25, False]
# ['INVEO', 42.76, False]
# ['INVES', 333.0, False]
# ['IPEKE', 38.2, False]
# ['ISATR', 3499997.5, False]
# ['ISBIR', 140.0, False]
# ['ISBTR', 799000.0, False]
# ['ISCTR', 16.18, False]
# ['ISDMR', 38.48, False]
# ['ISFIN', 15.43, False]
# ['ISGSY', 26.82, False]
# ['ISGYO', 15.73, False]
# ['ISKPL', 12.07, False]
# ['ISMEN', 34.4, False]
# ['ISSEN', 10.48, False]
# ['ISYAT', 9.7, False]
# ['IZENR', 22.7, False]
# ['IZFAS', 41.0, False]
# ['IZINV', 54.0, False]
# ['IZMDC', 6.47, False]
# ['JANTS', 31.0, False]
# ['KAPLM', 239.5, False]
# ['KAREL', 15.99, False]
# ['KARSN', 13.31, False]
# ['KARTN', 113.6, False]
# ['KARYE', 34.74, False]
# ['KATMR', 2.03, False]
# ['KAYSE', 27.46, False]
# ['KBORU', 85.0, False]
# ['KCAER', 54.55, False]
# ['KCHOL', 217.5, False]
# ['KENT', 1101.0, False]
# ['KERVN', 1.61, False]
# ['KERVT', 14.33, False]
# ['KFEIN', 138.0, False]
# ['KGYO', 35.36, False]
# ['KIMMR', 10.4, False]
# ['KLGYO', 5.54, False]
# ['KLKIM', 26.78, False]
# ['KLMSN', 28.4, False]
# ['KLNMA', 17.44, False]
# ['KLRHO', 34.0, False]
# ['KLSER', 46.6, False]
# ['KLSYN', 5.36, False]
# ['KMPUR', 57.0, False]
# ['KNFRT', 11.95, False]
# ['KOCMT', 18.3, False]
# ['KONKA', 50.25, False]
# ['KONTR', 175.2, False]
# ['KONYA', 8055.0, False]
# ['KOPOL', 37.58, False]
# ['KORDS', 92.5, False]
# ['KOTON', 23.84, False]
# ['KOZAA', 54.6, False]
# ['KOZAL', 21.44, False]
# ['KRDMA', 24.32, False]
# ['KRDMB', 22.54, False]
# ['KRDMD', 30.1, False]
# ['KRGYO', 25.62, False]
# ['KRONT', 22.7, False]
# ['KRPLS', 7.91, False]
# ['KRSTL', 7.67, False]
# ['KRTEK', 30.7, False]
# ['KRVGD', 25.9, False]
# ['KSTUR', 7750.0, False]
# ['KTLEV', 44.02, False]
# ['KTSKR', 70.5, False]
# ['KUTPO', 84.6, False]
# ['KUVVA', 46.08, False]
# ['KUYAS', 48.4, False]
# ['KZBGY', 24.2, False]
# ['KZGYO', 21.28, False]
# ['LIDER', 77.15, False]
# ['LIDFA', 8.44, False]
# ['LILAK', 28.18, False]
# ['LINK', 482.75, False]
# ['LKMNH', 105.2, False]
# ['LMKDC', 20.96, False]
# ['LOGO', 89.2, False]
# ['LRSHO', 3.73, False]
# ['LUKSK', 119.7, False]
# ['MAALT', 1146.0, False]
# ['MACKO', 82.55, False]
# ['MAGEN', 24.68, False]
# ['MAKIM', 30.44, False]
# ['MAKTK', 7.57, False]
# ['MANAS', 11.6, False]
# ['MARBL', 14.5, False]
# ['MARKA', 82.15, False]
# ['MARTI', 3.59, False]
# ['MAVI', 112.0, False]
# ['MEDTR', 33.26, False]
# ['MEGAP', 9.05, False]
# ['MEGMT', 35.5, False]
# ['MEKAG', 59.1, False]
# ['MEPET', 11.05, False]
# ['MERCN', 11.18, False]
# ['MERIT', 177.0, False]
# ['MERKO', 12.91, False]
# ['METRO', 2.71, False]
# ['METUR', 14.3, False]
# ['MGROS', 516.0, False]
# ['MHRGY', 4.65, False]
# ['MIATK', 56.5, False]
# ['MIPAZ', 80.4, False]
# ['MMCAS', 22.78, False]
# ['MNDRS', 15.13, False]
# ['MNDTR', 6.2, False]
# ['MOBTL', 5.7, False]
# ['MOGAN', 13.27, False]
# ['MPARK', 338.25, False]
# ['MPATA', 3110.0, False]
# ['MRGYO', 5.81, False]
# ['MRSHL', 1965.0, False]
# ['MSGYO', 13.7, False]
# ['MTRKS', 67.9, False]
# ['MTRYO', 8.97, False]
# ['MZHLD', 7.72, False]
# ['NATEN', 42.24, False]
# ['NETAS', 72.7, False]
# ['NIBAS', 17.25, False]
# ['NTGAZ', 16.13, False]
# ['NTHOL', 33.2, False]
# ['NUGYO', 7.93, False]
# ['NUHCM', 253.25, False]
# ['OBAMS', 37.18, False]
# ['OBASE', 40.16, False]
# ['ODAS', 8.53, False]
# ['ODINE', 60.75, False]
# ['OFSYM', 41.0, False]
# ['ONCSM', 136.0, False]
# ['ONRYT', 72.95, False]
# ['OPX30', 57.72, False]
# ['ORCAY', 11.39, False]
# ['ORGE', 64.55, False]
# ['ORMA', 259.0, False]
# ['OSMEN', 255.75, False]
# ['OSTIM', 5.98, False]
# ['OTKAR', 619.0, False]
# ['OTTO', 289.0, False]
# ['OYAKC', 61.25, False]
# ['OYAYO', 34.48, False]
# ['OYLUM', 10.38, False]
# ['OYYAT', 41.74, False]
# ['OZGYO', 5.8, False]
# ['OZKGY', 8.84, False]
# ['OZRDN', 58.9, False]
# ['OZSUB', 31.34, False]
# ['OZYSR', 26.88, False]
# ['PAGYO', 48.1, False]
# ['PAMEL', 119.3, False]
# ['PAPIL', 135.9, False]
# ['PARSN', 111.5, False]
# ['PASEU', 67.95, False]
# ['PATEK', 73.95, False]
# ['PCILT', 19.19, False]
# ['PEHOL', 25.08, False]
# ['PEKGY', 7.77, False]
# ['PENGD', 7.96, False]
# ['PENTA', 15.89, False]
# ['PETKM', 21.54, False]
# ['PETUN', 85.65, False]
# ['PGSUS', 230.3, False]
# ['PINSU', 25.48, False]
# ['PKART', 109.0, False]
# ['PKENT', 307.5, False]
# ['PLTUR', 17.06, False]
# ['PNLSN', 67.7, False]
# ['PNSUT', 84.5, False]
# ['POLHO', 13.27, False]
# ['POLTK', 9300.0, False]
# ['PRDGS', 6.5, False]
# ['PRKAB', 37.62, False]
# ['PRKME', 24.08, False]
# ['PRZMA', 35.52, False]
# ['PSDTC', 90.35, False]
# ['PSGYO', 6.02, False]
# ['QNBFB', 345.25, False]
# ['QNBFL', 134.9, False]
# ['QPERP', 5058.0, False]
# ['QTEMZ', 340.6, False]
# ['QUAGR', 3.41, False]
# ['RALYH', 204.9, False]
# ['RAYSG', 622.0, False]
# ['REEDR', 39.06, False]
# ['RGYAS', 131.1, False]
# ['RNPOL', 31.2, False]
# ['RODRG', 146.0, False]
# ['RPAVS', 5722.0, False]
# ['RPFGY', 4880.0, False]
# ['RTALB', 12.32, False]
# ['RUBNS', 32.84, True]
# ['RYGYO', 43.04, False]
# ['RYSAS', 50.75, False]
# ['SAFKR', 47.44, False]
# ['SAHOL', 93.85, False]
# ['SAMAT', 44.06, False]
# ['SANEL', 26.24, False]
# ['SANFM', 70.0, False]
# ['SANKO', 24.36, False]
# ['SARKY', 33.78, False]
# ['SASA', 44.36, False]
# ['SAYAS', 66.55, False]
# ['SDTTR', 283.5, False]
# ['SEGYO', 4.34, False]
# ['SEKFK', 9.81, False]
# ['SEKUR', 12.55, False]
# ['SELEC', 45.26, False]
# ['SELGD', 42.28, False]
# ['SELVA', 13.06, False]
# ['SEYKM', 8.54, False]
# ['SILVR', 20.3, False]
# ['SISE', 48.36, False]
# ['SKBNK', 3.72, False]
# ['SKTAS', 5.7, False]
# ['SKYLP', 122.0, False]
# ['SKYMD', 13.1, False]
# ['SMART', 36.32, False]
# ['SMRTG', 50.7, False]
# ['SNGYO', 5.01, False]
# ['SNICA', 7.2, False]
# ['SNKRN', 48.9, False]
# ['SNPAM', 87.95, False]
# ['SODSN', 151.2, False]
# ['SOKE', 14.63, False]
# ['SOKM', 64.15, False]
# ['SONME', 96.7, False]
# ['SRVGY', 288.0, False]
# ['SUMAS', 425.75, False]
# ['SUNTK', 17.99, False]
# ['SURGY', 48.82, False]
# ['SUWEN', 30.0, False]
# ['TABGD', 183.7, False]
# ['TARKM', 473.5, False]
# ['TATEN', 29.2, False]
# ['TATGD', 25.92, False]
# ['TAVHL', 244.1, False]
# ['TBORG', 103.9, False]
# ['TCELL', 98.6, False]
# ['TDGYO', 11.24, False]
# ['TEKTU', 4.89, False]
# ['TERA', 39.52, False]
# ['TETMT', 8575.0, False]
# ['TEZOL', 18.2, False]
# ['TGSAS', 65.95, False]
# ['THYAO', 311.75, False]
# ['TKFEN', 52.75, False]
# ['TKNSA', 34.58, False]
# ['TLMAN', 114.6, False]
# ['TMPOL', 80.5, False]
# ['TMSN', 138.5, False]
# ['TNZTP', 55.05, False]
# ['TOASO', 315.5, False]
# ['TRCAS', 27.2, False]
# ['TRGYO', 47.4, False]
# ['TRILC', 25.48, False]
# ['TSGYO', 14.01, False]
# ['TSKB', 11.41, False]
# ['TSPOR', 2.14, False]
# ['TTKOM', 48.68, False]
# ['TTRAK', 958.5, False]
# ['TUCLK', 13.33, False]
# ['TUKAS', 7.38, False]
# ['TUPRS', 167.0, False]
# ['TUREX', 62.5, False]
# ['TURGG', 597.5, False]
# ['TURSG', 78.35, False]
# ['UFUK', 440.0, False]
# ['ULAS', 24.0, False]
# ['ULKER', 155.1, False]
# ['ULUFA', 13.31, False]
# ['ULUSE', 175.2, False]
# ['ULUUN', 27.84, False]
# ['UMPAS', 11.64, False]
# ['UNLU', 16.5, False]
# ['USAK', 11.15, False]
# ['USDTR', 3076.0, False]
# ['UZERB', 800.5, False]
# ['VAKBN', 23.62, False]
# ['VAKFN', 3.24, False]
# ['VAKKO', 112.5, False]
# ['VANGD', 19.19, False]
# ['VBTYZ', 28.52, False]
# ['VERTU', 47.0, False]
# ['VERUS', 263.5, False]
# ['VESBE', 21.34, False]
# ['VESTL', 87.7, False]
# ['VKFYO', 25.56, False]
# ['VKGYO', 2.13, False]
# ['VKING', 39.2, False]
# ['VRGYO', 23.38, False]
# ['YAPRK', 442.0, False]
# ['YATAS', 37.4, False]
# ['YAYLA', 16.0, False]
# ['YBTAS', 184042.5, False]
# ['YEOTK', 187.5, False]
# ['YESIL', 4.64, False]
# ['YGGYO', 46.84, False]
# ['YGYO', 10.4, False]
# ['YIGIT', 27.34, False]
# ['YKBNK', 32.58, False]
# ['YKSLN', 21.46, False]
# ['YONGA', 77.65, False]
# ['YUNSA', 81.55, False]
# ['YYAPI', 6.67, False]
# ['YYLGD', 12.13, False]
# ['Z30EA', 135.2, False]
# ['Z30KE', 103.4, False]
# ['Z30KP', 149.0, False]
# ['ZEDUR', 11.2, False]
# ['ZELOT', 109.25, False]
# ['ZGOLD', 247.0, False]
# ['ZOREN', 5.44, False]
# ['ZPBDL', 156.9, False]
# ['ZPLIB', 168.3, False]
# ['ZPT10', 82.4, False]
# ['ZPX30', 148.2, False]
# ['ZRE20', 121.85, False]
# ['ZRGYO', 7.52, False]
# ['ZSR25', 39.53, False]
# ['ZTM15', 147.3, False]
#     Hisse Adı  Son Fiyat  Dip Sinyali
# 262     IHAAS      25.12         True
# 463     RUBNS      32.84         True
